# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df=pd.DataFrame(data)
df.describe
# Out:
# <bound method NDFrame.describe of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %%
np.mean(df)
# Out:
# age                             60.833893
# anaemia                          0.431438
# creatinine_phosphokinase       581.839465
# diabetes                         0.418060
# ejection_fraction               38.083612
# high_blood_pressure              0.351171
# platelets                   263358.029264
# serum_creatinine                 1.393880
# serum_sodium                   136.625418
# sex                              0.648829
# smoking                          0.321070
# time                           130.260870
# DEATH_EVENT                      0.321070
# dtype: float64

# %%
df['DEATH_EVENT'] = df['DEATH_EVENT'].map({0:'Alvie', 1:'Dead'})

# %%
plt.scatter(df["DEATH_EVENT"],df['age'])
plt.xlabel("Death Event")
plt.ylabel("Age")
plt.title("Age VS Death event")
plt.grid()

# %%
plt.scatter(df["DEATH_EVENT"],df['creatinine_phosphokinase'])
plt.xlabel("Death Event")
plt.ylabel("Creatinine Phosphokinase")
plt.title("Creatinine Phosphokinase VS Death event")
plt.grid()

# %%
plt.scatter(df["DEATH_EVENT"],df['creatinine_phosphokinase'])
plt.xlabel("Death Event")
plt.ylabel("Creatinine Phosphokinase")
plt.title("Creatinine Phosphokinase VS Death event")
plt.grid()

# %%
plt.scatter(df["DEATH_EVENT"],df['ejection_fraction'])
plt.xlabel("Death Event")
plt.ylabel("Ejection Fraction")
plt.title("Ejection Fraction VS Death event")
plt.grid()

# %%
plt.scatter(df["DEATH_EVENT"],df['platelets'])
plt.xlabel("Death Event")
plt.ylabel("Platelets")
plt.title("Platelets VS Death event")
plt.grid()

# %%
plt.scatter(df["DEATH_EVENT"],df['serum_creatinine'])
plt.xlabel("Death Event")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS Death event")
plt.grid()

# %%
plt.scatter(df["DEATH_EVENT"],df['serum_sodium'])
plt.xlabel("Death Event")
plt.ylabel("Serum Sodium")
plt.title("Serum Sodium VS Death event")
plt.grid()

# %%
df['anaemia'] = df['anaemia'].map({0:'No', 1:'Yes'})

# %%
plt.scatter(df["anaemia"],df['age'])
plt.xlabel("Anaemia")
plt.ylabel("Age")
plt.title("Age VS Anaemia")
plt.grid()

# %%
plt.scatter(df["anaemia"],df['creatinine_phosphokinase'])
plt.xlabel("Anaemia")
plt.ylabel("Creatinine Phosphokinase")
plt.title("Creatinine Phosphokinase VS Anaemia")
plt.grid()

# %%
plt.scatter(df["anaemia"],df['ejection_fraction'])
plt.xlabel("anaemia")
plt.ylabel("Ejection Fraction")
plt.title("Ejection Fraction VS Anaemia")
plt.grid()

# %%
plt.scatter(df["anaemia"],df['platelets'])
plt.xlabel("Anaemia")
plt.ylabel("Platelets")
plt.title("Platelets VS Anaemia")
plt.grid()

# %%
plt.scatter(df["anaemia"],df['serum_creatinine'])
plt.xlabel("Anaemia")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS Anaemia")
plt.grid()

# %%
plt.scatter(df["anaemia"],df['serum_sodium'])
plt.xlabel("Anaemia")
plt.ylabel("Serum Sodium")
plt.title("Serum Sodium VS Anaemia")
plt.grid()

# %%
df['diabetes'] = df['diabetes'].map({0:'No', 1:'Yes'})

# %%
plt.scatter(df["diabetes"],df['age'])
plt.xlabel("Diabetes")
plt.ylabel("Age")
plt.title("Age VS Diabetes")
plt.grid()

# %%
plt.scatter(df["diabetes"],df['creatinine_phosphokinase'])
plt.xlabel("Diabetes")
plt.ylabel("Creatinine Phosphokinase")
plt.title("Creatinine Phosphokinase VS Diabetes")
plt.grid()

# %%
plt.scatter(df["diabetes"],df['ejection_fraction'])
plt.xlabel("Diabetes")
plt.ylabel("Ejection Fraction")
plt.title("Ejection Fraction VS Diabetes")
plt.grid()

# %%
plt.scatter(df["diabetes"],df['platelets'])
plt.xlabel("Diabetes")
plt.ylabel("Platelets")
plt.title("Platelets VS Diabetes")
plt.grid()

# %%
plt.scatter(df["diabetes"],df['serum_creatinine'])
plt.xlabel("Diabetes")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS Diabetes")
plt.grid()

# %%
plt.scatter(df["diabetes"],df['serum_sodium'])
plt.xlabel("Diabetes")
plt.ylabel("Serum Sodium")
plt.title("Serum Sodium VS Diabetes")
plt.grid()

# %%
df['high_blood_pressure'] = df['high_blood_pressure'].map({0:'No', 1:'Yes'})

# %%
plt.scatter(df["high_blood_pressure"],df['age'])
plt.xlabel("High Blood Pressure")
plt.ylabel("Age")
plt.title("Age VS High Blood Pressure")
plt.grid()

# %%
plt.scatter(df["high_blood_pressure"],df['creatinine_phosphokinase'])
plt.xlabel("High Blood Pressure")
plt.ylabel("Creatinine Phosphokinase")
plt.title("Creatinine Phosphokinase VS High Blood Pressure")
plt.grid()

# %%
plt.scatter(df["high_blood_pressure"],df['ejection_fraction'])
plt.xlabel("High Blood Pressure")
plt.ylabel("Ejection Fraction")
plt.title("Ejection Fraction VS High Blood Pressure")
plt.grid()

# %%
plt.scatter(df["high_blood_pressure"],df['platelets'])
plt.xlabel("High Blood Pressure")
plt.ylabel("Platelets")
plt.title("Platelets VS High Blood Pressure")
plt.grid()

# %%
plt.scatter(df["high_blood_pressure"],df['serum_creatinine'])
plt.xlabel("High Blood Pressure")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS High Blood Pressure")
plt.grid()

# %%
plt.scatter(df["high_blood_pressure"],df['serum_creatinine'])
plt.xlabel("High Blood Pressure")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS High Blood Pressure")
plt.grid()

# %%
plt.scatter(df["high_blood_pressure"],df['serum_sodium'])
plt.xlabel("High Blood Pressure")
plt.ylabel("Serum Sodium")
plt.title("Serum Sodium VS High Blood Pressure")
plt.grid()

# %%
df['sex'] = df['sex'].map({0:'Female', 1:'Male'})

# %%
plt.scatter(df["sex"],df['age'])
plt.xlabel("Sex")
plt.ylabel("Age")
plt.title("Age VS Sex")
plt.grid()

# %%
plt.scatter(df["sex"],df['creatinine_phosphokinase'])
plt.xlabel("Sex")
plt.ylabel("Creatinine Phosphokinase")
plt.title("Creatinine Phosphokinase VS Sex")
plt.grid()

# %%
plt.scatter(df["sex"],df['ejection_fraction'])
plt.xlabel("Sex")
plt.ylabel("Ejection Fraction")
plt.title("Ejection Fraction VS Sex")
plt.grid()

# %%
plt.scatter(df["sex"],df['platelets'])
plt.xlabel("Diabetes")
plt.ylabel("Platelets")
plt.title("Platelets VS Sex")
plt.grid()

# %%
plt.scatter(df["sex"],df['serum_creatinine'])
plt.xlabel("Sex")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS Sex")
plt.grid()

# %%
plt.scatter(df["sex"],df['serum_creatinine'])
plt.xlabel("Sex")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS Sex")
plt.grid()

# %%
plt.scatter(df["sex"],df['serum_sodium'])
plt.xlabel("Sex")
plt.ylabel("Serum Sodium")
plt.title("Serum Sodium VS Sex")
plt.grid()

# %%
df['smoking'] = df['smoking'].map({0:'No', 1:'Yes'})

# %%
plt.scatter(df["smoking"],df['age'])
plt.xlabel("Smoking")
plt.ylabel("Age")
plt.title("Age VS Smoking")
plt.grid()

# %%
plt.scatter(df["smoking"],df['creatinine_phosphokinase'])
plt.xlabel("Smoking")
plt.ylabel("Creatinine Phosphokinase")
plt.title("Creatinine Phosphokinase VS Smoking")
plt.grid()

# %%
plt.scatter(df["smoking"],df['ejection_fraction'])
plt.xlabel("Smoking")
plt.ylabel("Ejection Fraction")
plt.title("Ejection Fraction VS Smoking")
plt.grid()

# %%
plt.scatter(df["smoking"],df['platelets'])
plt.xlabel("Smoking")
plt.ylabel("Platelets")
plt.title("Platelets VS Smoking")
plt.grid()

# %%
plt.scatter(df["smoking"],df['serum_creatinine'])
plt.xlabel("Smoking")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS Smoking")
plt.grid()

# %%
plt.scatter(df["smoking"],df['serum_creatinine'])
plt.xlabel("Smoking")
plt.ylabel("Serum Creatinine")
plt.title("Serum Creatinine VS Smoking")
plt.grid()

# %%
plt.scatter(df["smoking"],df['serum_sodium'])
plt.xlabel("Smoking")
plt.ylabel("Serum Sodium")
plt.title("Serum Sodium VS Smoking")
plt.grid()

# %%
plt.scatter(df["creatinine_phosphokinase"],df['ejection_fraction'])
plt.xlabel("Creatinine Phosphokinase")
plt.ylabel("Ejection Fraction")
plt.title("creatinine phosphokinase VS Ejection Fraction")
plt.grid()

# %%
plt.scatter(df["creatinine_phosphokinase"],df['platelets'])
plt.xlabel("Creatinine Phosphokinase")
plt.ylabel("Platelets")
plt.title("Creatinine Phosphokinase VS Platelets")
plt.grid()

# %%
plt.scatter(df["creatinine_phosphokinase"],df['serum_creatinine'])
plt.xlabel("Creatinine phosphokinase")
plt.ylabel("Serum Creatinine")
plt.title("Creatinine Phosphokinase VS Serum creatinine")
plt.grid()

# %%
plt.scatter(df["creatinine_phosphokinase"],df['serum_sodium'])
plt.xlabel("Creatinine Phosphokinase")
plt.ylabel("Serum Sodium")
plt.title("Creatinine Phosphokinase VS Serum Sodium")
plt.grid()

# %%
plt.scatter(df["ejection_fraction"],df['platelets'])
plt.xlabel("ejection_fraction")
plt.ylabel("platelets")
plt.title("Ejection Fraction VS Platelets")
plt.grid()

# %%
plt.scatter(df["ejection_fraction"],df['serum_creatinine'])
plt.xlabel("Ejection Fraction")
plt.ylabel("Serum Creatinine")
plt.title("Ejection Fraction VS serum Creatinine")
plt.grid()

# %%
plt.scatter(df["ejection_fraction"],df['serum_sodium'])
plt.xlabel("Ejection Fraction")
plt.ylabel("Serum Sodium")
plt.title("Ejection fraction VS Serum sodium")
plt.grid()

# %%
plt.scatter(df["serum_creatinine"],df['serum_sodium'])
plt.xlabel("Serum Creatinine")
plt.ylabel("Serum Sodium")
plt.title("Serum creatinine VS Serum Sodium")
plt.grid()
